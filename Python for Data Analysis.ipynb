Pakistan,PK,2012,
Pakistan,PK,2013,
Sri Lanka,LK,1960,57.86
Sri Lanka,LK,1961,58.2
Sri Lanka,LK,1962,58.55
Sri Lanka,LK,1963,58.93
Sri Lanka,LK,1964,59.35
Sri Lanka,LK,1965,59.82
Sri Lanka,LK,1966,60.35
Sri Lanka,LK,1967,60.91
Sri Lanka,LK,1968,61.5
Sri Lanka,LK,1969,62.1
Sri Lanka,LK,1970,62.71
Sri Lanka,LK,1971,63.31
Sri Lanka,LK,1972,63.9
Sri Lanka,LK,1973,64.47
Sri Lanka,LK,1974,65.02
Sri Lanka,LK,1975,65.56
Sri Lanka,LK,1976,66.1
Sri Lanka,LK,1977,66.64
Sri Lanka,LK,1978,67.19
Sri Lanka,LK,1979,67.72
Sri Lanka,LK,1980,68.22
Sri Lanka,LK,1981,68.65
Sri Lanka,LK,1982,68.97
Sri Lanka,LK,1983,69.19
Sri Lanka,LK,1984,69.32
Sri Lanka,LK,1985,69.37
Sri Lanka,LK,1986,69.39
Sri Lanka,LK,1987,69.42
Sri Lanka,LK,1988,69.48
Sri Lanka,LK,1989,69.58
Sri Lanka,LK,1990,69.68
Sri Lanka,LK,1991,69.73
Sri Lanka,LK,1992,69.7
Sri Lanka,LK,1993,69.58
Sri Lanka,LK,1994,69.4
Sri Lanka,LK,1995,69.23
Sri Lanka,LK,1996,69.18
Sri Lanka,LK,1997,69.32
Sri Lanka,LK,1998,69.68
Sri Lanka,LK,1999,70.25
Sri Lanka,LK,2000,70.98
Sri Lanka,LK,2001,71.78
Sri Lanka,LK,2002,72.54
Sri Lanka,LK,2003,73.18
Sri Lanka,LK,2004,73.67
Sri Lanka,LK,2005,73.99
Sri Lanka,LK,2006,74.18
Sri Lanka,LK,2007,74.31
Sri Lanka,LK,2008,74.43
Sri Lanka,LK,2009,74.57
Sri Lanka,LK,2010,74.72
Sri Lanka,LK,2011,74.9
Sri Lanka,LK,2012,
Sri Lanka,LK,2013,

# %% [markdown]
# ### Load data

# %%
import pandas as pd
data = pd.read_csv('data/theglobaleconomy_life_expectancy.csv')
data
# Out:
#         Country code  year  Life expectancy  in years
# 0   Afghanistan   AF  1960                      31.13
# 1   Afghanistan   AF  1961                      31.48
# 2   Afghanistan   AF  1962                      31.83
# 3   Afghanistan   AF  1963                      32.20
# 4   Afghanistan   AF  1964                      32.59
# 5   Afghanistan   AF  1965                      32.99
# 6   Afghanistan   AF  1966                      33.40
# 7   Afghanistan   AF  1967                      33.81
# 8   Afghanistan   AF  1968                      34.22
# 9   Afghanistan   AF  1969                      34.64
# 10  Afghanistan   AF  1970                      35.06
# 11  Afghanistan   AF  1971                      35.48
# 12  Afghanistan   AF  1972                      35.92
# 13  Afghanistan   AF  1973                      36.36
# 14  Afghanistan   AF  1974                      36.81
# 15  Afghanistan   AF  1975                      37.26
# ...

# %%
data.head()
# Out:
#        Country code  year  Life expectancy  in years
# 0  Afghanistan   AF  1960                      31.13
# 1  Afghanistan   AF  1961                      31.48
# 2  Afghanistan   AF  1962                      31.83
# 3  Afghanistan   AF  1963                      32.20
# 4  Afghanistan   AF  1964                      32.59
#
# [5 rows x 4 columns]

# %%
data.tail(6)
# Out:
#        Country code  year  Life expectancy  in years
# 426  Sri Lanka   LK  2008                      74.43
# 427  Sri Lanka   LK  2009                      74.57
# 428  Sri Lanka   LK  2010                      74.72
# 429  Sri Lanka   LK  2011                      74.90
# 430  Sri Lanka   LK  2012                        NaN
# 431  Sri Lanka   LK  2013                        NaN
#
# [6 rows x 4 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.core.frame.DataFrame?

# %% [markdown]
# ###Clean Data

# %%
data.columns
# Out:
# Index([u'Country', u'code', u'year', u'Life expectancy  in years'], dtype='object')

# %%
ndata = data.rename(columns={'Life expectancy  in years' : 'Expectancy', 'code' : 'Code', 'year': 'Year'})
ndata.columns
# Out:
# Index([u'Country', u'Code', u'Year', u'Expectancy'], dtype='object')

# %% [markdown]
# Set the **inplace = True** flag# incase you want to modify the existing DataFrame. Look carefully the data type. It is dtype='object'. But why?

# %%
#ndata.fillna(0)
#ndata.fillbymen (need to check)
#fill with interpolate
#fill with mean

# %%
ndata.dropna(inplace=True)
ndata
# Out:
#         Country Code  Year  Expectancy
# 0   Afghanistan   AF  1960       31.13
# 1   Afghanistan   AF  1961       31.48
# 2   Afghanistan   AF  1962       31.83
# 3   Afghanistan   AF  1963       32.20
# 4   Afghanistan   AF  1964       32.59
# 5   Afghanistan   AF  1965       32.99
# 6   Afghanistan   AF  1966       33.40
# 7   Afghanistan   AF  1967       33.81
# 8   Afghanistan   AF  1968       34.22
# 9   Afghanistan   AF  1969       34.64
# 10  Afghanistan   AF  1970       35.06
# 11  Afghanistan   AF  1971       35.48
# 12  Afghanistan   AF  1972       35.92
# 13  Afghanistan   AF  1973       36.36
# 14  Afghanistan   AF  1974       36.81
# 15  Afghanistan   AF  1975       37.26
# 16  Afghanistan   AF  1976       37.69
# 17  Afghanistan   AF  1977       38.11
# 18  Afghanistan   AF  1978       38.50
# 19  Afghanistan   AF  1979       38.86
# 20  Afghanistan   AF  1980       39.20
# 21  Afghanistan   AF  1981       39.53
# 22  Afghanistan   AF  1982       39.84
# ...

# %%
pd.isnull(ndata['Expectancy']).tail(5)
# Out:
# 425    False
# 426    False
# 427    False
# 428    False
# 429    False
# Name: Expectancy, dtype: bool

# %% [markdown]
# ###Statiscal Analysis

# %%
data.describe()
# Out:
#               year  Life expectancy  in years
# count   432.000000                 416.000000
# mean   1986.500000                  54.900264
# std      15.603855                  10.930985
# min    1960.000000                  31.130000
# 25%    1973.000000                  45.820000
# 50%    1986.500000                  56.345000
# 75%    2000.000000                  63.720000
# max    2013.000000                  76.880000
#
# [8 rows x 2 columns]

# %% [markdown]
# Look carefully the count of both column. It's not same. Because there are few Nan values there. It's negelecting non numeric columns also.

# %%
ndata.describe()
# Out:
#               Year  Expectancy
# count   416.000000  416.000000
# mean   1985.500000   54.900264
# std      15.026402   10.930985
# min    1960.000000   31.130000
# 25%    1972.750000   45.820000
# 50%    1985.500000   56.345000
# 75%    1998.250000   63.720000
# max    2011.000000   76.880000
#
# [8 rows x 2 columns]

# %% [markdown]
# ####Group By

# %%
ndata.groupby(['Year']).mean().head(5)
# Out:
#       Expectancy
# Year
# 1960    42.36125
# 1961    42.80875
# 1962    43.27875
# 1963    43.77500
# 1964    44.28375
#
# [5 rows x 1 columns]

# %%
ndata.groupby(['Year', 'Code']).mean().head(10)
# Out:
#            Expectancy
# Year Code
# 1960 AF         31.13
#      BD         47.76
#      BT         37.08
#      IN         42.45
#      LK         57.86
#      MV         37.48
#      NP         38.49
#      PK         46.64
# 1961 AF         31.48
#      BD         48.24
#
# [10 rows x 1 columns]

# %%
ndata.groupby(['Country'])['Expectancy'].mean()
# Out:
# Country
# Afghanistan    40.453654
# Bangladesh     56.206346
# Bhutan         50.904615
# India          55.849038
# Maldives       57.419038
# Nepal          52.306154
# Pakistan       58.355962
# Sri Lanka      67.707308
# Name: Expectancy, dtype: float64

# %%
ndata.groupby(['Country'])['Expectancy'].describe()
# Out:
# Country
# Afghanistan  count    52.000000
#              mean     40.453654
#              std       5.150446
#              min      31.130000
#              25%      36.250000
#              50%      40.925000
#              75%      44.792500
#              max      48.680000
# Bangladesh   count    52.000000
#              mean     56.206346
#              std       8.896892
#              min      38.970000
#              25%      49.265000
#              50%      57.185000
#              75%      63.847500
# ...
# Pakistan   mean     58.355962
#            std       5.349490
#            min      46.640000
#            25%      54.792500
#            50%      59.550000
#            75%      62.792500
#            max      65.450000
# Sri Lanka  count    52.000000
#            mean     67.707308
#            std       4.908061
#            min      57.860000
#            25%      64.327500
#            50%      69.275000
#            75%      69.860000
# ...

# %% [markdown]
# ####Sorting

# %%
sdata = ndata.groupby(['Country'])['Expectancy'].mean().copy()
type(sdata)
# Out:
# pandas.core.series.Series

# %%
pd.core.series.Series?

# %%
sdata.sort()
sdata
# Out:
# Country
# Afghanistan    40.453654
# Bhutan         50.904615
# Nepal          52.306154
# India          55.849038
# Bangladesh     56.206346
# Maldives       57.419038
# Pakistan       58.355962
# Sri Lanka      67.707308
# Name: Expectancy, dtype: float64

# %% [markdown]
# ####Filter By

# %%
bdata = ndata[ndata['Code'] == 'BD']
bdata
# Out:
#         Country Code  Year  Expectancy
# 54   Bangladesh   BD  1960       47.76
# 55   Bangladesh   BD  1961       48.24
# 56   Bangladesh   BD  1962       48.80
# 57   Bangladesh   BD  1963       49.42
# 58   Bangladesh   BD  1964       49.98
# 59   Bangladesh   BD  1965       50.23
# 60   Bangladesh   BD  1966       49.83
# 61   Bangladesh   BD  1967       48.67
# 62   Bangladesh   BD  1968       46.78
# 63   Bangladesh   BD  1969       44.37
# 64   Bangladesh   BD  1970       41.89
# 65   Bangladesh   BD  1971       39.93
# 66   Bangladesh   BD  1972       38.97
# 67   Bangladesh   BD  1973       39.25
# 68   Bangladesh   BD  1974       40.79
# 69   Bangladesh   BD  1975       43.33
# 70   Bangladesh   BD  1976       46.45
# 71   Bangladesh   BD  1977       49.53
# 72   Bangladesh   BD  1978       52.13
# 73   Bangladesh   BD  1979       54.05
# 74   Bangladesh   BD  1980       55.24
# 75   Bangladesh   BD  1981       55.81
# 76   Bangladesh   BD  1982       56.08
# ...

# %%
bdata.describe()
# Out:
#               Year  Expectancy
# count    52.000000   52.000000
# mean   1985.500000   56.206346
# std      15.154757    8.896892
# min    1960.000000   38.970000
# 25%    1972.750000   49.265000
# 50%    1985.500000   57.185000
# 75%    1998.250000   63.847500
# max    2011.000000   68.940000
#
# [8 rows x 2 columns]

# %%
bdata.median()
# Out:
# Year          1985.500
# Expectancy      57.185
# dtype: float64

# %%
bdata[bdata['Year'] > 1970].describe()
# Out:
#               Year  Expectancy
# count    41.000000   41.000000
# mean   1991.000000   58.457561
# std      11.979149    8.642249
# min    1971.000000   38.970000
# 25%    1981.000000   55.810000
# 50%    1991.000000   59.990000
# 75%    2001.000000   65.210000
# max    2011.000000   68.940000
#
# [8 rows x 2 columns]

# %% [markdown]
# ####Single column operation

# %%
ndata.Year.median()
# Out:
# 1985.5

# %%
ndata.Expectancy.count()
# Out:
# 416

# %% [markdown]
# ###Data Visualization

# %%
ndata.plot()

# %%
#Bangladesh Life Expectancy
bdata.plot(x='Year', y='Expectancy')

# %%
from matplotlib import pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(12,6))
bddata=ndata[ndata['Code'] == 'BD']
ax.plot(bddata.Year, bddata.Expectancy, color='r', label="Bangladesh", alpha=0.73)
afdata=ndata[ndata['Code'] == 'AF']
ax.plot(afdata.Year, afdata.Expectancy, color='g', label="Afghanistan")
btdata=ndata[ndata['Code'] == 'BT']
ax.plot(btdata.Year, btdata.Expectancy, color='b', label="Bhutan")
indata=ndata[ndata['Code'] == 'IN']
ax.plot(indata.Year, indata.Expectancy, color='y', label="India")
lkdata=ndata[ndata['Code'] == 'LK']
ax.plot(lkdata.Year, lkdata.Expectancy, color='c', label="Sri Lanka")
mvdata=ndata[ndata['Code'] == 'MV']
ax.plot(mvdata.Year, mvdata.Expectancy, color='m', label="Maldives")
npdata=ndata[ndata['Code'] == 'NP']
ax.plot(npdata.Year, npdata.Expectancy, color='k', label="Nepal")
pkdata=ndata[ndata['Code'] == 'PK']
ax.plot(pkdata.Year, pkdata.Expectancy, color='grey', label="Pakistan")
ax.legend(loc=0, fontsize=15)

# %%
#mean by country
sdata
# Out:
# Country
# Afghanistan    40.453654
# Bhutan         50.904615
# Nepal          52.306154
# India          55.849038
# Bangladesh     56.206346
# Maldives       57.419038
# Pakistan       58.355962
# Sri Lanka      67.707308
# Name: Expectancy, dtype: float64

# %%
plt.figure()
sdata.plot(kind='bar')

# %%
df = ndata.pivot_table('Expectancy', ['Year'], 'Country')
df.head(5)
# Out:
# Country  Afghanistan  Bangladesh  Bhutan  India  Maldives  Nepal  Pakistan  \
# Year
# 1960           31.13       47.76   37.08  42.45     37.48  38.49     46.64
# 1961           31.48       48.24   37.31  43.10     37.97  38.84     47.33
# 1962           31.83       48.80   37.58  43.76     38.51  39.20     48.00
# 1963           32.20       49.42   37.87  44.43     39.11  39.57     48.67
# 1964           32.59       49.98   38.18  45.11     39.76  39.96     49.34
#
# Country  Sri Lanka
# Year
# 1960         57.86
# 1961         58.20
# 1962         58.55
# 1963         58.93
# 1964         59.35
#
# [5 rows x 8 columns]

# %%
df.tail(10).plot(kind='bar', figsize=(20, 6))

# %% [markdown]
# ### All in a single figure

# %%
fig, axes = plt.subplots(2,2, figsize=(20,12))
f1 = bdata.plot(x='Year', y='Expectancy', ax=axes[0][0], title="Bangladesh Life Expectancy(1960-2011)")
f1.set_ylabel("Life Expectancy(years)")
f2 = df.plot(ax=axes[0][1], title="Life Expectancy Comparison of South Asia Countries")
f2.legend()
f2.set_ylabel("Life Expectancy(years)")
f3 = sdata.plot(kind='bar', ax=axes[1][0], title="Mean Life Expectany by Country")
f3.set_ylabel("Life Expectancy(years)")
f4 = df.tail(5).plot(kind='bar', ax=axes[1][1])
f4.set_ylabel("Life Expectancy(years)")

# %% [markdown]
# ###Save figure

# %%
fig.savefig("data/lif_expectancy.png")
fig.savefig("data/lif_expectancy.pdf")

# %% [markdown]
# ##Bangladeshi Life Expectancy Prediction
# ###Supervised Learning: Classification and regression
# In **Supervised Learning**, we have a dataset consisting of both features and labels. The task is to construct an estimator which is able to predict the label of an object given the set of features. A relatively simple example is predicting the species of iris given a set of measurements of its flower.
#
# Supervised learning is further broken down into two categories, **classification** and **regression**. In classification, the label is discrete, while in regression, the label is continuous. For example, in astronomy, the task of determining whether an object is a star, a galaxy, or a quasar is a classification problem: the label is from three distinct categories. On the other hand, we might wish to estimate the age of an object based on such observations: this would be a regression problem, because the label (age) is a continuous quantity.
#
# ###Unsupervised Learning
# **Unsupervised** Learning addresses a different sort of problem. Here the data has no labels, and we are interested in finding similarities between the objects in question. In a sense, you can think of unsupervised learning as a means of discovering labels from the data itself. Unsupervised learning comprises tasks such as dimensionality reduction, clustering, and density estimation. For example, in the iris data discussed above, we can used unsupervised methods to determine combinations of the measurements which best display the structure of the data

# %%
bdata.tail(4)
# Out:
#         Country Code  Year  Expectancy
# 102  Bangladesh   BD  2008       68.00
# 103  Bangladesh   BD  2009       68.33
# 104  Bangladesh   BD  2010       68.63
# 105  Bangladesh   BD  2011       68.94
#
# [4 rows x 4 columns]

# %%
#Fit a linear regression to it
from sklearn.linear_model import LinearRegression
import numpy as np
model = LinearRegression(fit_intercept=True)
X_train = bdata.Year[:, np.newaxis]
y_train = bdata.Expectancy
model.fit(X_train, y_train)
print "Model coefficient: %.5f, and intercept: %.5f" % (model.coef_, model.intercept_)
X_test = np.array([2013, 2015, 2020, 2050, 2100])[:, np.newaxis]
predicted = model.predict(X_test)
predicted
# Out:
# Model coefficient: 0.53358, and intercept: -1003.21547
# array([  70.87977845,   71.94693716,   74.61483395,   90.62221463,
#         117.30118245])

# %%
import pylab as pl
pl.plot(X_train.squeeze(), y_train, 'o')
pl.plot(X_test.squeeze(), predicted)

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(bdata.Year[:, np.newaxis], bdata.Expectancy)

# %%
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
predicted = clf.predict(X_test)
expected = y_test

# %%
plt.scatter(expected, predicted)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('True Expectancy')
plt.ylabel('Predicted Expectancy')
from sklearn.metrics import mean_squared_error
print "MSE:", mean_squared_error(y_test, predicted)   
print "RMS:", np.sqrt(np.mean((predicted - expected) ** 2))
# Out:
# MSE: 18.730178797
# RMS: 4.32783765835

# %% [markdown]
# ##Example 2 : Analysis of Brac Data

# %%
path = os.getcwd()
files = os.listdir(path+'/data/')
files
# Out:
# ['.DS_Store',
#  'adder (1).py',
#  'input1.xlsx',
#  'input2.xlsx',
#  'lif_expectancy.pdf',
#  'lif_expectancy.png',
#  'output.xls',
#  'spreadsheet-combine-example.py',
#  'theglobaleconomy_life_expectancy.csv']

# %%
files_xls = [f for f in files if f[-4:] == 'xlsx']
files_xls
# Out:
# ['input1.xlsx', 'input2.xlsx']

# %%
df = pd.DataFrame()
for f in files_xls:
    data = pd.read_excel("data/"+f, 'January', header=1, skiprows=1)
    df = df.append(data)
    data = pd.read_excel("data/"+f, 'February', header=1, skiprows=1)
    df = df.append(data, ignore_index=True)

# %%
#look pd.merge(df,other,on='str_col',how='inner')
df
# Out:
#     Matlab         Upazila:
# 0      NaN              NaN
# 1        1      TB Positive
# 2        5   Smear Positive
# 3       10   Smear Negative
# 4      NaN              NaN
# 5        2      TB Positive
# 6        4   Smear Positive
# 7       11   Smear Negative
# 8      NaN              NaN
# 9       20       New births
# 10      40  New pregnancies
# 11     100    Immunizations
# 12     NaN              NaN
# 13      30       New births
# 14      50  New pregnancies
# 15     110    Immunizations
#
# [16 rows x 2 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#     Matlab         Upazila:
# 1        1      TB Positive
# 2        5   Smear Positive
# 3       10   Smear Negative
# 5        2      TB Positive
# 6        4   Smear Positive
# 7       11   Smear Negative
# 9       20       New births
# 10      40  New pregnancies
# 11     100    Immunizations
# 13      30       New births
# 14      50  New pregnancies
# 15     110    Immunizations
#
# [12 rows x 2 columns]

# %%
ndf = df.groupby(['Upazila:']).sum()
ndf
# Out:
#                  Matlab
# Upazila:
# Immunizations       210
# New births           50
# New pregnancies      90
# Smear Negative       21
# Smear Positive        9
# TB Positive           3
#
# [6 rows x 1 columns]

# %%
ndf.describe()
# Out:
#            Matlab
# count    6.000000
# mean    63.833333
# std     78.463792
# min      3.000000
# 25%     12.000000
# 50%     35.500000
# 75%     80.000000
# max    210.000000
#
# [8 rows x 1 columns]

# %%
ndf.to_excel('result.xlsx', sheet_name='Yearly Sum')

# %%
ndf.plot()
